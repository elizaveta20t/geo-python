# %%
ice_cream_rating = 8
sleep_rating = 10

# %%
first_name = 'Elizaveta'
last_name = 'Tugi'
my_name = (first_name, last_name)

# %%
happiness_rating = (ice_cream_rating + sleep_rating) / 2

# %% [markdown]
# print(type(ice_cream_rating))
# print(type(first_name))
# print(type(happiness_rating))

# %%
print('Меня зовут', (first_name), ', и я ставлю мороженому', (ice_cream_rating),' баллов из 10!')
print('Я', (first_name), (last_name), ', и мой рейтинг удовольствия от сна - ', (sleep_rating), 'из 10!')
print('Исходя из вышеперечисленных факторов, мой рейтинг счастья составляет', (happiness_rating), 'из 10, или', (happiness_rating*10), '%!')
# Out:
# Меня зовут Elizaveta , и я ставлю мороженому 8  баллов из 10!
# Я Elizaveta Tugi , и мой рейтинг удовольствия от сна -  10 из 10!
# Исходя из вышеперечисленных факторов, мой рейтинг счастья составляет 9.0 из 10, или 90.0 %!
